# %% [markdown]
# # Cubist Regression Tree to Predict Age

# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.tree import DecisionTreeRegressor
import sklearn.metrics as metrics
import matplotlib.pyplot as plt
import seaborn as sb
from cubist import Cubist

# %% [markdown]
# # Data

# %%
data = pd.read_csv("./Volumetric_features.csv")

data_features = pd.DataFrame(data, columns = data.columns[:-1])
data_features = data_features.drop(['S.No','Age'], axis=1)

data_features.head()
data_features.describe()
# Out:
#        Left-Lateral-Ventricle  Left-Inf-Lat-Vent  \
# count             4226.000000        4226.000000
# mean             13370.040795         574.849716
# std               9194.928348         594.590387
# min               2204.100000           0.000000
# 25%               7031.625000         243.200000
# 50%              10669.950000         385.800000
# 75%              17332.650000         720.825000
# max              79812.500000        7533.800000
#
#        Left-Cerebellum-White-Matter  Left-Cerebellum-Cortex  Left-Thalamus  \
# count                   4226.000000             4226.000000    4226.000000
# mean                   14646.696711            52002.811571    7164.947539
# std                     2622.868798             6378.435917    1207.229615
# min                     6920.100000            29911.800000    4145.400000
# 25%                    12909.875000            47359.675000    6239.425000
# ...

# %% [markdown]
# # Training

# %%
# Split out train data, 80%, and the rest, 20%
X_train, X_rest, Y_train, Y_rest = train_test_split(data_features, data['Age'], test_size=0.20, random_state=33)
# Spit out validate data, 15% (of total, 75% of X_rest), and test, 5% (of total, 25% of rest)
X_validate, X_test, Y_validate, Y_test = train_test_split(X_rest, Y_rest, test_size=0.25, random_state=37)

rules = [100, 250, 500, 600, 700, 750, 800, 900, 1000]
train_accuracy = np.empty(len(rules))
validation_accuracy = np.empty(len(rules))

for i, rule in enumerate(rules):
    model = Cubist(n_rules=rule)
    model.fit(X_train, Y_train)
    
    Y_pred_train = model.predict(X_train)
    Y_pred_validate = model.predict(X_validate)
    
    train_accuracy[i] = metrics.mean_squared_error(Y_train, Y_pred_train)
    validation_accuracy[i] = metrics.mean_squared_error(Y_validate, Y_pred_validate)

plt.plot(rules, validation_accuracy, label='Validation Set MSE')
plt.plot(rules, train_accuracy, label='Training Set MSE')

plt.legend()
plt.xlabel('n_rules')
plt.ylabel('Mean Squared Error')
plt.show()

# %% [markdown]
# As shown above, n_rules seems to be best at 700-800

# %% [markdown]
# # Testing

# %%
cubic_tree = Cubist(n_rules=750)
cubic_tree.fit(X_train, Y_train)
Y_pred = cubic_tree.predict(X_test)

print("Explained variance: " + str(metrics.explained_variance_score(Y_test, Y_pred)))
print("Max Error: " + str(metrics.max_error(Y_test, Y_pred)))
print("Mean absolute error: " + str(metrics.mean_absolute_error(Y_test, Y_pred)))
print("Mean squared error: " + str(metrics.mean_absolute_error(Y_test, Y_pred)))
# Out:
# Explained variance: 0.8669856856184744
# Max Error: 26.519771575927734
# Mean absolute error: 5.65636005941427
# Mean squared error: 5.65636005941427
